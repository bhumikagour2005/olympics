# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("athlete_events.csv")

# %%
data.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# ...

# %%
data.tail()
# Out:
#             ID                Name Sex   Age  Height  Weight      Team  NOC  \
# 271111  135569          Andrzej ya   M  29.0   179.0    89.0  Poland-1  POL
# 271112  135570            Piotr ya   M  27.0   176.0    59.0    Poland  POL
# 271113  135570            Piotr ya   M  27.0   176.0    59.0    Poland  POL
# 271114  135571  Tomasz Ireneusz ya   M  30.0   185.0    96.0    Poland  POL
# 271115  135571  Tomasz Ireneusz ya   M  34.0   185.0    96.0    Poland  POL
#
#               Games  Year  Season            City        Sport  \
# 271111  1976 Winter  1976  Winter       Innsbruck         Luge
# 271112  2014 Winter  2014  Winter           Sochi  Ski Jumping
# 271113  2014 Winter  2014  Winter           Sochi  Ski Jumping
# 271114  1998 Winter  1998  Winter          Nagano    Bobsleigh
# 271115  2002 Winter  2002  Winter  Salt Lake City    Bobsleigh
#
#                                            Event Medal
# 271111                Luge Mixed (Men)'s Doubles   NaN
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271116 entries, 0 to 271115
# Data columns (total 15 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   ID      271116 non-null  int64
#  1   Name    271116 non-null  object
#  2   Sex     271116 non-null  object
#  3   Age     261642 non-null  float64
#  4   Height  210945 non-null  float64
#  5   Weight  208241 non-null  float64
#  6   Team    271116 non-null  object
#  7   NOC     271116 non-null  object
#  8   Games   271116 non-null  object
#  9   Year    271116 non-null  int64
#  10  Season  271116 non-null  object
#  11  City    271116 non-null  object
#  12  Sport   271116 non-null  object
#  13  Event   271116 non-null  object
#  14  Medal   39783 non-null   object
# dtypes: float64(3), int64(2), object(10)
# memory usage: 31.0+ MB

# %%
data.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 271111    False
# 271112    False
# 271113    False
# 271114    False
# 271115    False
# Length: 271116, dtype: bool

# %%
data.duplicated().sum()
# Out:
# np.int64(1385)

# %%
data.drop_duplicates()
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 0            1                 A Dijiang   M  24.0   180.0    80.0
# 1            2                  A Lamusi   M  23.0   170.0    60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                   Team  NOC        Games  Year  Season            City  \
# 0                China  CHN  1992 Summer  1992  Summer       Barcelona
# ...

# %%
data.drop_duplicates(inplace=True)

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
data.isnull().sum()
#isnull ki jagah 'isna' bhi likh sakte hai
# Out:
# ID             0
# Name           0
# Sex            0
# Age         9315
# Height     58814
# Weight     61527
# Team           0
# NOC            0
# Games          0
# Year           0
# Season         0
# City           0
# Sport          0
# Event          0
# Medal     229959
# dtype: int64

# %%
data["Medal"].unique()
# Out:
# array([nan, 'Gold', 'Bronze', 'Silver'], dtype=object)

# %%
data["Medal"].value_counts()
# Out:
# Medal
# Gold      13369
# Bronze    13295
# Silver    13108
# Name: count, dtype: int64

# %%
data["Age"].fillna((data["Age"].mean) , inplace=True)
# Out:
# C:\Users\k\AppData\Local\Temp\ipykernel_2092\1188278076.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '<bound method Series.mean of 0         24.0
# 1         23.0
# 2         24.0
# 3         34.0
# 4         21.0
#           ...
# 271111    29.0
# 271112    27.0
# 271113    27.0
# 271114    30.0
# 271115    34.0
# Name: Age, Length: 269731, dtype: float64>' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   data["Age"].fillna((data["Age"].mean) , inplace=True)

# %%
data["Age"].mean
# Out:
# <bound method Series.mean of 0         24.0
# 1         23.0
# 2         24.0
# 3         34.0
# 4         21.0
#           ...
# 271111    29.0
# 271112    27.0
# 271113    27.0
# 271114    30.0
# 271115    34.0
# Name: Age, Length: 269731, dtype: object>

# %%
data["Height"]=data["Height"].fillna((data["Height"].mean ), inplace=True)
# Out:
# C:\Users\k\AppData\Local\Temp\ipykernel_2092\267441922.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '<bound method Series.mean of 0         180.0
# 1         170.0
# 2           NaN
# 3           NaN
# 4         185.0
#           ...
# 271111    179.0
# 271112    176.0
# 271113    176.0
# 271114    185.0
# 271115    185.0
# Name: Height, Length: 269731, dtype: float64>' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   data["Height"]=data["Height"].fillna((data["Height"].mean ), inplace=True)

# %%
data["Weight"].fillna((data["Weight"].mean) , inplace=True)
# Out:
# C:\Users\k\AppData\Local\Temp\ipykernel_2092\593201182.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '<bound method Series.mean of 0         80.0
# 1         60.0
# 2          NaN
# 3          NaN
# 4         82.0
#           ...
# 271111    89.0
# 271112    59.0
# 271113    59.0
# 271114    96.0
# 271115    96.0
# Name: Weight, Length: 269731, dtype: float64>' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   data["Weight"].fillna((data["Weight"].mean) , inplace=True)

# %%
data.isnull().sum()
# Out:
# ID             0
# Name           0
# Sex            0
# Age            0
# Height    269731
# Weight         0
# Team           0
# NOC            0
# Games          0
# Year           0
# Season         0
# City           0
# Sport          0
# Event          0
# Medal     229959
# dtype: int64

# %%
data["Sex"].value_counts()
# Out:
# Sex
# M    195353
# F     74378
# Name: count, dtype: int64

# %%
year_sports=data.groupby("Year")["Sport"].nunique()
plt.Figure()
plt.plot(year_sports.index, year_sports.values)
plt.title("year vs no.of sports")
plt.xlabel("year")
plt.ylabel("number of sports")
plt.show()

# %%
data["Sport"].value_counts()
# Out:
# Sport
# Athletics        38624
# Gymnastics       26707
# Swimming         23195
# Shooting         11448
# Cycling          10827
#                  ...
# Racquets            12
# Jeu De Paume        11
# Roque                4
# Basque Pelota        2
# Aeronautics          1
# Name: count, Length: 66, dtype: int64

# %%
data["Sport"].unique()
# Out:
# array(['Basketball', 'Judo', 'Football', 'Tug-Of-War', 'Speed Skating',
#        'Cross Country Skiing', 'Athletics', 'Ice Hockey', 'Swimming',
#        'Badminton', 'Sailing', 'Biathlon', 'Gymnastics',
#        'Art Competitions', 'Alpine Skiing', 'Handball', 'Weightlifting',
#        'Wrestling', 'Luge', 'Water Polo', 'Hockey', 'Rowing', 'Bobsleigh',
#        'Fencing', 'Equestrianism', 'Shooting', 'Boxing', 'Taekwondo',
#        'Cycling', 'Diving', 'Canoeing', 'Tennis', 'Modern Pentathlon',
#        'Figure Skating', 'Golf', 'Softball', 'Archery', 'Volleyball',
#        'Synchronized Swimming', 'Table Tennis', 'Nordic Combined',
#        'Baseball', 'Rhythmic Gymnastics', 'Freestyle Skiing',
#        'Rugby Sevens', 'Trampolining', 'Beach Volleyball', 'Triathlon',
#        'Ski Jumping', 'Curling', 'Snowboarding', 'Rugby',
#        'Short Track Speed Skating', 'Skeleton', 'Lacrosse', 'Polo',
#        'Cricket', 'Racquets', 'Motorboating', 'Military Ski Patrol',
# ...

# %%
data["Medal"].fillna("No medal" , inplace=True)
# Out:
# C:\Users\k\AppData\Local\Temp\ipykernel_2092\1748453679.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data["Medal"].fillna("No medal" , inplace=True)

# %%
data["Medal"].value_counts()
# Out:
# Medal
# No medal    229959
# Gold         13369
# Bronze       13295
# Silver       13108
# Name: count, dtype: int64

# %%
data[data["Medal"]!="No medal"].value_counts().sum()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\k\Desktop\olmpics_data_analysis\olmpic\Lib\site-packages\pandas\core\algorithms.py:1516, in safe_sort(values, codes, use_na_sentinel, assume_unique, verify)
#    1515 try:
# -> 1516     sorter = values.argsort()
#    1517     ordered = values.take(sorter)
#
# TypeError: '<' not supported between instances of 'method' and 'float'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# File c:\Users\k\Desktop\olmpics_data_analysis\olmpic\Lib\site-packages\numpy\_core\fromnumeric.py:54, in _wrapfunc(obj, method, *args, **kwds)
#      53 try:
# ---> 54     return bound(*args, **kwds)
#      55 except TypeError:
#      56     # A TypeError occurs if the object does have such a method in its
# ...

# %%
data[data["Medal"]!="No medal"].groupby("Sport")["Medal"].count().sort_values(ascending=False).head(10)
# Out:
# Sport
# Athletics     3969
# Swimming      3048
# Rowing        2945
# Gymnastics    2256
# Fencing       1743
# Football      1571
# Ice Hockey    1530
# Hockey        1528
# Wrestling     1296
# Cycling       1263
# Name: Medal, dtype: int64

# %%
data["Sport"].nunique()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 data["Sport"].nunique()
#
# NameError: name 'data' is not defined

# %%
data.groupby("Year")["Sport"].nunique()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 data.groupby("Year")["Sport"].nunique()
#
# NameError: name 'data' is not defined

# %%
data["Year"].nunique()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 data["Year"].nunique()
#
# NameError: name 'data' is not defined
